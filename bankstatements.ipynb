# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import LabelEncoder
import re

# %%
#loading the csv file
#assuming the file is named 'Bank_statements.csv'
df=pd.read_csv('Bank_statements.csv')
#displaying the first few rows of the dataframe
print(df.head())
#knowing about the datatypes of the columns
print(df.dtypes)
# Out:
#                                          DESCRIPTION        DATE AMOUNT  \
# 0  Dear UPI user A/C X5904 debited by 10.0 on dat...  02-06-2025     10
# 1  Getepay has requested Rs31720 frm u on Google ...      08-Jun  31720
# 2  Dear SBI User, your A/c X5904-credited by Rs.1...  18-07-2025    180
# 3  Dear UPI user A/C X5904 debited by 900.0 on da...  23-07-2025    900
# 4  Dear SBI User, your A/c X5904-credited by Rs.2...  29-07-2025     20
#
#   TRANSACTION TYPE                               Merchant
# 0          debited                            Diwan Chand
# 1          debited                                Getepay
# 2         credited                            Rohit Kumar
# 3          debited                         SIDARTH SHARMA
# 4         credited  GOOGLE INDIA DIGITAL SERVICES PVT LTD
# DESCRIPTION         object
# DATE                object
# AMOUNT              object
# TRANSACTION TYPE    object
# Merchant            object
# dtype: object

# %%
#checking for duplicates
print(df.duplicated().sum())
#no duplicate value is there in the dataset
#checking for missing values
print(df.isnull().sum())
# Out:
# 0
# DESCRIPTION          0
# DATE                 0
# AMOUNT               0
# TRANSACTION TYPE     0
# Merchant            15
# dtype: int64

# %%
#since the missing value is of type object, we can fill it with a placeholder such as 'Unknown'
df['Merchant']=df['Merchant'].fillna('Unknown')
print(df.isnull().sum()) # Verifying that there are no more missing values
# Out:
# DESCRIPTION         0
# DATE                0
# AMOUNT              0
# TRANSACTION TYPE    0
# Merchant            0
# dtype: int64

# %%
#converting the 'Date' column to datetime format 
#since the date in the csv file is in 'dd/mm/yyyy' format
df['DATE'] = pd.to_datetime(df['DATE'],format='mixed', errors='coerce')
#displaying the first few rows after conversion 
print(df.head())
print(df.tail())
# Out:
#                                          DESCRIPTION       DATE AMOUNT  \
# 0  Dear UPI user A/C X5904 debited by 10.0 on dat... 2025-02-06     10
# 1  Getepay has requested Rs31720 frm u on Google ...        NaT  31720
# 2  Dear SBI User, your A/c X5904-credited by Rs.1... 2025-07-18    180
# 3  Dear UPI user A/C X5904 debited by 900.0 on da... 2025-07-23    900
# 4  Dear SBI User, your A/c X5904-credited by Rs.2... 2025-07-29     20
#
#   TRANSACTION TYPE                               Merchant
# 0          debited                            Diwan Chand
# 1          debited                                Getepay
# 2         credited                            Rohit Kumar
# 3          debited                         SIDARTH SHARMA
# 4         credited  GOOGLE INDIA DIGITAL SERVICES PVT LTD
#                                             DESCRIPTION       DATE    AMOUNT  \
# 1194  INR 13826.97 has been successfully credited to... 2025-01-31  13826.97
# 1195  INR 30263.44 has been successfully credited to... 2025-06-06  30263.44
# 1196  INR 34488.53 has been successfully credited to... 2025-07-25  34488.53
# 1197  INR 9832.49 has been successfully credited to ... 2025-01-21   9832.49
# 1198  INR 26786.01 has been successfully credited to... 2025-02-16  26786.01
#
#      TRANSACTION TYPE           Merchant
# 1194         credited           DIVIDEND
# 1195         credited             REFUND
# 1196         credited       GOVT SUBSIDY
# 1197         credited  LOAN DISBURSEMENT
# 1198         credited          FREELANCE

# %%
print(df.head())
print(df.tail())
#checking the data types again to confirm the conversion   
print(df.dtypes)
print(df.isnull().sum())
#filling missing values in the 'DATE' column with a placeholder date, here we use '2025-01-01'
df['DATE']=df['DATE'].fillna(pd.Timestamp("2025-01-01"))
print(df.isnull().sum())
# Out:
#                                          DESCRIPTION       DATE AMOUNT  \
# 0  Dear UPI user A/C X5904 debited by 10.0 on dat... 2025-02-06     10
# 1  Getepay has requested Rs31720 frm u on Google ...        NaT  31720
# 2  Dear SBI User, your A/c X5904-credited by Rs.1... 2025-07-18    180
# 3  Dear UPI user A/C X5904 debited by 900.0 on da... 2025-07-23    900
# 4  Dear SBI User, your A/c X5904-credited by Rs.2... 2025-07-29     20
#
#   TRANSACTION TYPE                               Merchant
# 0          debited                            Diwan Chand
# 1          debited                                Getepay
# 2         credited                            Rohit Kumar
# 3          debited                         SIDARTH SHARMA
# 4         credited  GOOGLE INDIA DIGITAL SERVICES PVT LTD
#                                             DESCRIPTION       DATE    AMOUNT  \
# 1194  INR 13826.97 has been successfully credited to... 2025-01-31  13826.97
# 1195  INR 30263.44 has been successfully credited to... 2025-06-06  30263.44
# 1196  INR 34488.53 has been successfully credited to... 2025-07-25  34488.53
# 1197  INR 9832.49 has been successfully credited to ... 2025-01-21   9832.49
# 1198  INR 26786.01 has been successfully credited to... 2025-02-16  26786.01
#
#      TRANSACTION TYPE           Merchant
# 1194         credited           DIVIDEND
# 1195         credited             REFUND
# 1196         credited       GOVT SUBSIDY
# 1197         credited  LOAN DISBURSEMENT
# 1198         credited          FREELANCE
# DESCRIPTION                 object
# DATE                datetime64[ns]
# AMOUNT                      object
# TRANSACTION TYPE            object
# Merchant                    object
# dtype: object
# DESCRIPTION         0
# DATE                3
# AMOUNT              0
# TRANSACTION TYPE    0
# Merchant            0
# dtype: int64
# DESCRIPTION         0
# DATE                0
# AMOUNT              0
# TRANSACTION TYPE    0
# Merchant            0
# dtype: int64

# %%
#converting the 'AMOUNT' column to numeric, handling errors by coercing them to NaN
df['AMOUNT'] = pd.to_numeric(df['AMOUNT'], errors='coerce')
#checking the data types again to confirm the conversion
print(df.dtypes)
#standardizing the 'Merchant' column by converting it to lowercase
df['Merchant'] = df['Merchant'].str.lower()
#removing any leading or trailing whitespace from the 'Merchant' column
df['Merchant'] = df['Merchant'].str.strip()
#removing multiple in-word spaces in the 'Merchant' column
df['Merchant'] = df['Merchant'].str.replace(r'\s+', ' ', regex=True)
#displaying the first few rows after standardization   
print(df.head())
# Standardize the capitalization of the 'TRANSACTION TYPE' column by converting to lowercase
df['TRANSACTION TYPE'] = df['TRANSACTION TYPE'].str.lower()
#standardizing the 'DESCRIPTION' column by converting it to lowercase
df['DESCRIPTION'] = df['DESCRIPTION'].str.lower()
#removing any leading or trailing whitespace from the 'DESCRIPTION' column
df['DESCRIPTION'] = df['DESCRIPTION'].str.strip()   
#removing multiple in-word spaces in the 'DESCRIPTION' column 
df['DESCRIPTION'] = df['DESCRIPTION'].str.replace(r'\s+', ' ', regex=True)
#removing special characters from the 'DESCRIPTION' column
df['DESCRIPTION'] = df['DESCRIPTION'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
#extracting reference numbers from the 'DESCRIPTION' column using regex
# Out:
# DESCRIPTION                 object
# DATE                datetime64[ns]
# AMOUNT                     float64
# TRANSACTION TYPE            object
# Merchant                    object
# dtype: object
#                                          DESCRIPTION       DATE   AMOUNT  \
# 0  Dear UPI user A/C X5904 debited by 10.0 on dat... 2025-02-06     10.0
# 1  Getepay has requested Rs31720 frm u on Google ... 2025-01-01  31720.0
# 2  Dear SBI User, your A/c X5904-credited by Rs.1... 2025-07-18    180.0
# 3  Dear UPI user A/C X5904 debited by 900.0 on da... 2025-07-23    900.0
# 4  Dear SBI User, your A/c X5904-credited by Rs.2... 2025-07-29     20.0
#
#   TRANSACTION TYPE                               Merchant
# 0          debited                            diwan chand
# 1          debited                                getepay
# 2         credited                            rohit kumar
# 3          debited                         sidarth sharma
# 4         credited  google india digital services pvt ltd

# %%
def extract_ref_no(DESCRIPTION):
    # This regex looks for digits that come after 'Refno' or 'Ref:'or"Ref No" or "Transaction ID:" or "Transaction"

    # It captures the digits that follow these keywords.
    # The 're.IGNORECASE' flag makes the search case-insensitive.
    # The '|' operator acts as an OR condition between different patterns.
    # The pattern '\d+' matches one or more digits.
    match = re.search(r'Refno\s*(\d+)|Ref:\s*(\d+)|Ref No\s*(\d+)|Transaction ID:\s*(\d+)|Transaction\s*(\d+)', DESCRIPTION, re.IGNORECASE)
    if match:
        # Return the first group that has a match
        return match.group(1) or match.group(2) or match.group(3) or match.group(4) or match.group(5)
    return None

# Apply the function to the 'Description' column
df['Reference_Number'] = df['DESCRIPTION'].apply(extract_ref_no)

# Display the new column to verify
print(df[['DESCRIPTION', 'Reference_Number']].head(10))
#filling NaN values in the 'Reference_Number' column with '515394903436'
df['Reference_Number'] = df['Reference_Number'].fillna('515394903436')
print(df[['DESCRIPTION', 'Reference_Number']].head(10))
#Feature enginnering 
df["Year"]=df["DATE"].dt.year
df["Month"]=df["DATE"].dt.month
df["Day"]=df["DATE"].dt.day
print(df.head())
# Out:
#                                          DESCRIPTION Reference_Number
# 0  dear upi user ac x5904 debited by 100 on date ...     515394903435
# 1  getepay has requested rs31720 frm u on google ...             None
# 2  dear sbi user your ac x5904credited by rs180 o...     519961126008
# 3  dear upi user ac x5904 debited by 9000 on date...     520444832884
# 4  dear sbi user your ac x5904credited by rs20 on...     300930472105
# 5  dear sbi user your ac x5904credited by rs700 o...     521064388958
# 6  dear sbi user your ac x5904credited by rs30 on...     521230915626
# 7  dear upi user ac x5904 debited by 10480 on dat...     521239310919
# 8  dear upi user ac x5904 debited by 850 on date ...     520884630374
# 9  dear sbi user your ac x5904credited by rs100 o...     869017163974
#                                          DESCRIPTION Reference_Number
# 0  dear upi user ac x5904 debited by 100 on date ...     515394903435
# 1  getepay has requested rs31720 frm u on google ...     515394903436
# 2  dear sbi user your ac x5904credited by rs180 o...     519961126008
# 3  dear upi user ac x5904 debited by 9000 on date...     520444832884
# 4  dear sbi user your ac x5904credited by rs20 on...     300930472105
# 5  dear sbi user your ac x5904credited by rs700 o...     521064388958
# 6  dear sbi user your ac x5904credited by rs30 on...     521230915626
# 7  dear upi user ac x5904 debited by 10480 on dat...     521239310919
# 8  dear upi user ac x5904 debited by 850 on date ...     520884630374
# 9  dear sbi user your ac x5904credited by rs100 o...     869017163974
#                                          DESCRIPTION       DATE   AMOUNT  \
# 0  dear upi user ac x5904 debited by 100 on date ... 2025-02-06     10.0
# 1  getepay has requested rs31720 frm u on google ... 2025-01-01  31720.0
# 2  dear sbi user your ac x5904credited by rs180 o... 2025-07-18    180.0
# 3  dear upi user ac x5904 debited by 9000 on date... 2025-07-23    900.0
# 4  dear sbi user your ac x5904credited by rs20 on... 2025-07-29     20.0
#
#   TRANSACTION TYPE                               Merchant Reference_Number  \
# 0          debited                            diwan chand     515394903435
# 1          debited                                getepay     515394903436
# 2         credited                            rohit kumar     519961126008
# 3          debited                         sidarth sharma     520444832884
# 4         credited  google india digital services pvt ltd     300930472105
#
#    Year  Month  Day
# 0  2025      2    6
# 1  2025      1    1
# 2  2025      7   18
# 3  2025      7   23
# 4  2025      7   29

# %%
#fearture engineering for categorization of merchants
# Define the category mapping based on the unique merchant list
category_mapping = {
    'Food & Dining': ['zomato','kfc' ,'swiggy', 'dominos', 'food court', 'gupta cafe', 'thakur confectio'],
    'Shopping': ['amazon', 'myntra', 'flipkart', 'paytm mall', 'jio mart', 'big bazaar', "spencer's", 'reliance fresh', 'nykaa', 'jk readymade ga'],
    'Bills & Utilities': ['jio','vi recharge' ,'jio recharge', 'mobile bill', 'internet bill', 'water bill', 'gas agency','google india digital services pvt ltd', 'electricity bill', 'electricity', 'broadband', 'postpaid','jioin app direct','google india dig'],
    'Groceries': ['grocery','reliance retail', 'd-mart', 'nature basket', 'more super market', 'star bazaar', 'bigbasket'],
    'Fuel & Transportation': ['petrol pump', 'fuel', 'indian oil', 'bharat petroleum', 'hpcl', 'shell', 'esso'],
    'Transportation': ['uber', 'ola', 'rapido'],
    'Entertainment': ['netflix', 'spotify', 'prime video', 'hotstar', 'bookmyshow', 'mx player', 'zee5','spotify india pvt ltd', 'google play music', 'google youtube music', 'google youtube prem' ,'youtube premium','youtube music'],
    'Income': ['salary','govt subsidy','freelance' ,'credit interest', 'interest','bonus','cashback', 'refund', 'dividend', 'upi', 'neft', 'imps', 'rtgs'],
    'Education': ['unacademy', 'udemy','byjus', 'upgrad', 'coursera', 'edx'],
    'Health & Wellness': ['practo','medplus', '1mg', 'pharmacy', 'medlife','pharmeasy'],
    'Travel': ['make my trip', 'goibibo', 'redbus', 'yatra'],
    'Gifts & Donations': ['donation', 'charity'], 
    'Financial': ['loan', 'credit card payment', 'refund', 'dividend', 'getepay', 'airtel payments bank', 'flipkart payments'],
    'Rent': ['rent', 'pg rent', 'rent transfer'],
    'Personal & Others': ['diwan chand', 'rohit kumar', 'sidarth sharma', 'shivam choudhary', 'pranav sharma', 'kanan verma', 'ishani verma', 'suraj sharma', 'sunil kumar', 'om prakash', 'arun kumar', 'raj kumar so hukam singh', 'sahil', 'unknown', 'ujjwal katoch', 'nikhil bhardwaj', 'vinod kumar s o', 'mrs bhavana dev', 'sharma shudh vai', 'ravi kumar', 'ravinder prakash', 'shrestha thakur', 'jagdish ram and', 'piyush sharma', 'guru prashad so', 'rahul thakur', 'narender kumar', 'mahender pal', 'rashmi rana', 'rahul mehta']
}
# Create a categorization function
def categorize_merchant(merchant):
    # Iterate through the category mapping to find a match
    for category, keywords in category_mapping.items():
        for keyword in keywords:
            if keyword in merchant:
                return category
    return 'Other'
#hlo so is the above logic is ready 
# Apply the function to create the new 'Category' column
df['Category'] = df['Merchant'].apply(categorize_merchant)


# Print the value counts for the new 'Category' column
print("Breakdown of transactions by the new category:")
print(df['Category'].value_counts())
# Out:
# Breakdown of transactions by the new category:
# Category
# Shopping             195
# Other                176
# Income               164
# Bills & Utilities    122
# Personal & Others    121
# Food & Dining         82
# Entertainment         61
# Health & Wellness     60
# Rent                  56
# Education             52
# Transportation        31
# Financial             27
# Groceries             26
# Travel                26
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# 1. Clean the AMOUNT column
# Remove currency symbols or commas if they exist, then convert to numeric
# errors='coerce' turns non-convertible values into NaN so your code doesn't crash
df['AMOUNT'] = df['AMOUNT'].astype(str).str.replace(',', '').str.replace('$', '')
df['AMOUNT'] = pd.to_numeric(df['AMOUNT'], errors='coerce')

# 2. (Optional) Fill NaN values if any rows failed conversion
df['AMOUNT'] = df['AMOUNT'].fillna(0)

# 3. Create the Signed Amount column
# Now that AMOUNT is a number, the negative sign (-) will work
df['Signed Amount'] = np.where(df['TRANSACTION TYPE'] == 'credited', df['AMOUNT'], -df['AMOUNT'])

# 4. Label Encoding
le = LabelEncoder()
# Ensure TRANSACTION TYPE is a string to avoid encoding errors
df["TRANSACTION TYPE"] = df["TRANSACTION TYPE"].astype(str)
df["Transaction Type Encoded"] = le.fit_transform(df["TRANSACTION TYPE"])

print(df.head())
# Out:
#                                          DESCRIPTION       DATE   AMOUNT  \
# 0  dear upi user ac x5904 debited by 100 on date ... 2025-02-06     10.0
# 1  getepay has requested rs31720 frm u on google ... 2025-01-01  31720.0
# 2  dear sbi user your ac x5904credited by rs180 o... 2025-07-18    180.0
# 3  dear upi user ac x5904 debited by 9000 on date... 2025-07-23    900.0
# 4  dear sbi user your ac x5904credited by rs20 on... 2025-07-29     20.0
#
#   TRANSACTION TYPE                               Merchant Reference_Number  \
# 0          debited                            diwan chand     515394903435
# 1          debited                                getepay     515394903436
# 2         credited                            rohit kumar     519961126008
# 3          debited                         sidarth sharma     520444832884
# 4         credited  google india digital services pvt ltd     300930472105
#
#    Year  Month  Day           Category  Signed Amount  \
# 0  2025      2    6  Personal & Others          -10.0
# 1  2025      1    1          Financial       -31720.0
# 2  2025      7   18  Personal & Others          180.0
# 3  2025      7   23  Personal & Others         -900.0
# 4  2025      7   29  Bills & Utilities           20.0
#
#    Transaction Type Encoded
# 0                         1
# 1                         1
# 2                         0
# 3                         1
# 4                         0

# %%
#for converting the text description into vectors
 
from sklearn.feature_extraction.text import TfidfVectorizer
#this tfidfvectorizer will help in converting the text data into numerical format
import joblib
#for dumping the pickle file for future use 
#term frequency-inverse document frequency is what tfidf stands for 
# Initialize the TF-IDF Vectorizer
# I'll use stop_words='english' to remove common English words that don't add much value.
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
#this above  is the initialization of the tfidf vectorizer
#that is the above will contain the list of stop words


# Fit and transform the 'DESCRIPTION' column
tfidf_matrix = tfidf_vectorizer.fit_transform(df['DESCRIPTION'])

# Print the shape of the resulting matrix
print(f"Shape of the TF-IDF matrix: {tfidf_matrix.shape}")
# Save the TF-IDF matrix and the vectorizer object
np.savez_compressed('tfidf_matrix.npz', data=tfidf_matrix.data, indices=tfidf_matrix.indices, indptr=tfidf_matrix.indptr, shape=tfidf_matrix.shape)
joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.pkl')#storing the stopwords in the pkl file for the future refernce 

print("TF-IDF matrix saved to 'tfidf_matrix.npz'")#.npz is the compressed file format for storign the numpy arrays and matrices in a zipped format
print("TF-IDF vectorizer object saved to 'tfidf_vectorizer.pkl'")#this pkl that is pickle file  are used to store the python objects and we can use them in the future as they are working before

df.to_csv("Preprocessed bank statements.csv",index=False)#the index=False is there because it will not store index column 
# now we will  fit our model
# Out:
# Shape of the TF-IDF matrix: (1199, 4039)
# TF-IDF matrix saved to 'tfidf_matrix.npz'
# TF-IDF vectorizer object saved to 'tfidf_vectorizer.pkl'

# %%
# --- Train and Save Models for Category and Transaction Type ---

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
import joblib

# 1. Train the 'Category' model
print("--- Training the 'Category' Model ---")

y_category = df["Category"]

X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(
    tfidf_matrix,
    y_category,
    test_size=0.2,
    random_state=42,
    stratify=y_category
)

# Handle class imbalance with SMOTE
smote = SMOTE(random_state=42)
X_train_resampled_cat, y_train_resampled_cat = smote.fit_resample(X_train_cat, y_train_cat)

model_cat = LogisticRegression(max_iter=1000, random_state=42)
model_cat.fit(X_train_resampled_cat, y_train_resampled_cat)

# Evaluate the Category model
y_category_pred = model_cat.predict(X_test_cat)
print("Classification Report for 'Category' model:")
print(classification_report(y_test_cat, y_category_pred))

# Save the Category model
joblib.dump(model_cat, "trained_model.pkl")
print("Trained 'Category' model saved as 'trained_model.pkl'\n")

# 2. Train the 'Transaction Type' model
print("--- Training the 'Transaction Type' Model ---")

y_type = df["TRANSACTION TYPE"]

X_train_type, X_test_type, y_train_type, y_test_type = train_test_split(
    tfidf_matrix,
    y_type,
    test_size=0.2,
    random_state=42,
    stratify=y_type
)

model_type = LogisticRegression(max_iter=1000, random_state=42)
model_type.fit(X_train_type, y_train_type)

# Evaluate the Transaction Type model
y_pred_type = model_type.predict(X_test_type)
print("Classification Report for 'Transaction Type' model:")
print(classification_report(y_test_type, y_pred_type))

# Save the Transaction Type model
joblib.dump(model_type, "transaction_type_model.pkl")
print("Trained 'Transaction Type' model saved as 'transaction_type_model.pkl'")
# Out:
# --- Training the 'Category' Model ---
# Classification Report for 'Category' model:
#                    precision    recall  f1-score   support
#
# Bills & Utilities       0.96      0.92      0.94        25
#         Education       1.00      1.00      1.00        11
#     Entertainment       1.00      1.00      1.00        12
#         Financial       1.00      1.00      1.00         5
#     Food & Dining       1.00      0.88      0.94        17
#         Groceries       1.00      1.00      1.00         5
# Health & Wellness       1.00      1.00      1.00        12
#            Income       0.89      1.00      0.94        33
#             Other       1.00      0.89      0.94        35
# Personal & Others       0.86      1.00      0.92        24
#              Rent       1.00      1.00      1.00        11
#          Shopping       0.97      0.95      0.96        39
#    Transportation       1.00      1.00      1.00         6
#            Travel       1.00      1.00      1.00         5
#
#          accuracy                           0.96       240
#         macro avg       0.98      0.97      0.97       240
#      weighted avg       0.96      0.96      0.96       240
#
# Trained 'Category' model saved as 'trained_model.pkl'
#
# --- Training the 'Transaction Type' Model ---
# Classification Report for 'Transaction Type' model:
#               precision    recall  f1-score   support
#
#     credited       1.00      0.89      0.94        46
#      debited       0.97      1.00      0.99       194
#
#     accuracy                           0.98       240
#    macro avg       0.99      0.95      0.96       240
# weighted avg       0.98      0.98      0.98       240
#
# Trained 'Transaction Type' model saved as 'transaction_type_model.pkl'

# %%
import joblib

# 1. Load vectorizer and models
print("Loading vectorizer and models...")

tfidf_vectorizer = joblib.load("tfidf_vectorizer.pkl")
category_model = joblib.load("trained_model.pkl")
type_model = joblib.load("transaction_type_model.pkl")

print("Loaded successfully.")

def predict_for_description(description: str):
    """
    Predict Category and Transaction Type for a new transaction description.
    """
    # Vectorize the text
    X = tfidf_vectorizer.transform([description])

    # Predict category and transaction type
    pred_category = category_model.predict(X)[0]
    pred_type = type_model.predict(X)[0]

    print(f"\nDescription : {description!r}")
    #this is for putting'' arounf the description 
    print(f"Category    : {pred_category}")
    print(f"Trans. Type : {pred_type}")
    return pred_category, pred_type

# Example: change this string to test other descriptions
if __name__ == "__main__":
    new_description = "rs 5000 debited into your bank account on 24 august by refund from zomato"
    predict_for_description(new_description)
# Out:
# Loading vectorizer and models...
# Loaded successfully.
#
# Description : 'rs 5000 debited into your bank account on 24 august by refund from zomato'
# Category    : Food & Dining
# Trans. Type : debited
